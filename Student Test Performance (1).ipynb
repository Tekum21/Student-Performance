# %% [markdown]
# # Background of Study!

# %% [markdown]
# > Standardized testing has been a cornerstone of the educational system for a long time.Standardized testing measures a student’s progress throughout their education journey. According to Henry (2007), a standardized test is “an examination made up of uniform items which can be replicated, typically by asking short multiple choice questions which can be easily and cheaply scored by machine”.The use of standardized testing have expanded in the United States since 2002 after the passage of the No Child Left Behind Act by President George W.Bush, causing some observers to state that standardized testing is causing a “teaching to the test” mentality, which undermines America’s ability to produce innovators, imagination, and critical thinkers. Others state that these standardized exams are a fair and objective way to measure students' abilities. Besides the debate on whether standardized testing is a good indicator of student progress, there is also debate on whether certain factors; teachers role, family support, school environment, peer relationship and the most important factor is the socioeconomic status of parents have influnece on a student’s test score and general performance. School districts have tried to manipulate and change certain factors of the educational system to accommodate for these influences, with the goal of subpressing the negative impacts associated with students test scores.The poject below is design to investigate how students' performance in a standardized math, reading and writing test is affected by, their gender, parental level of education, lunch and test preparation course. It also try to investigate relationships between these variables.
# <a id="the_top"></a>

# %% [markdown]
# ## Libraries used for visualization include:
# * Pandas
# * Numpy
# * Matplotlib
# * Seaborn

# %%
#step1: importing the libraries we shall be using.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os
warnings.filterwarnings('ignore')

# %%
#Step2:Importing our dataset in the form of a csv file.
df=pd.read_csv('Students-Performance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#Step3: We read all the headings in our dataset.
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
#Step4: We find out how many rows and columns our dataset contains.
df.shape
# Out:
# (1000, 8)

# %%
#Step5: We select our working headings by droping that which is not important to our studies.

df=df.drop(columns=["race/ethnicity"])
df
# Out:
#      gender parental level of education         lunch test preparation course  \
# 0    female           bachelor's degree      standard                    none
# 1    female                some college      standard               completed
# 2    female             master's degree      standard                    none
# 3      male          associate's degree  free/reduced                    none
# 4      male                some college      standard                    none
# ..      ...                         ...           ...                     ...
# 995  female             master's degree      standard               completed
# 996    male                 high school  free/reduced                    none
# 997  female                 high school  free/reduced               completed
# 998  female                some college      standard               completed
# 999  female                some college  free/reduced                    none
#
# ...

# %%
# Adding a column to display each students' total score in the three test.
df["Total Score "]=df.iloc[:,4:].sum(axis=1)
df
# Out:
#      gender parental level of education         lunch test preparation course  \
# 0    female           bachelor's degree      standard                    none
# 1    female                some college      standard               completed
# 2    female             master's degree      standard                    none
# 3      male          associate's degree  free/reduced                    none
# 4      male                some college      standard                    none
# ..      ...                         ...           ...                     ...
# 995  female             master's degree      standard               completed
# 996    male                 high school  free/reduced                    none
# 997  female                 high school  free/reduced               completed
# 998  female                some college      standard               completed
# 999  female                some college  free/reduced                    none
#
# ...

# %%
# We try to find out some statistical summary of our dataset.
df.describe()
# Out:
#        math score  reading score  writing score  Total Score
# count  1000.00000    1000.000000    1000.000000   1000.000000
# mean     66.08900      69.169000      68.054000    203.312000
# std      15.16308      14.600192      15.195657     42.771978
# min       0.00000      17.000000      10.000000     27.000000
# 25%      57.00000      59.000000      57.750000    175.000000
# 50%      66.00000      70.000000      69.000000    205.000000
# 75%      77.00000      79.000000      79.000000    233.000000
# max     100.00000     100.000000     100.000000    300.000000

# %% [markdown]
# ### Visual display of some variables using the Histogram.

# %%
# Display or investigate students' general performance in reading.

bins=[25,50,75,100]
df.hist("reading score",bins=bins,figsize=(8,8))
Av_Reading=69.1
color="red"
plt.axvline(Av_Reading,color=color,label="Av_Reading")
plt.legend()
plt.show()

# %%
# Display or investigate students' general performance in writing.

bins=[25,50,75,100]
df.hist("writing score",bins=bins,figsize=(8,8))
Av_Writing=68.1
color="red"
plt.axvline(Av_Writing,color=color,label="Av_Writing")
plt.legend()
plt.show()

# %%
# Display or investigate students' general performance in math.

bins=[25,50,75,100]
df.hist("math score",bins=bins,figsize=(8,8))
Av_Math=66.1
color="red"
plt.axvline(Av_Math,color=color,label="Av_Math")
plt.legend()
plt.show()

# %% [markdown]
# ### Interpreting the above Histograms
#
# ##### *From the three displayed histograms above, we can see that more than half of the students scored above the mean mark in all three test.*

# %% [markdown]
# ## Investigating trends using scatter Plots.

# %%
# Displaying a scatter plot for math and reading scores.

fig, ax = plt.subplots(figsize=(8,8))  
ax.scatter(df['math score'],df['reading score'])
ax.set_title('reading score Vs math score', fontsize=10,color="red")
ax.set_xlabel('reading score', fontsize=10,color='red')
ax.set_ylabel('math score', fontsize=10,color='red')
# Out:
# Text(0, 0.5, 'math score')

# %%
# Displaying a scatter plot of reading and writing scores.

fig, ax=plt.subplots(figsize=(8,8))
ax.scatter(df['reading score'],df['writing score'])
ax.set_title("reading score Vs writing score", fontsize=10,color="red")
ax.set_xlabel('reading score',fontsize=10,color='red')
ax.set_ylabel('writing score',fontsize=10,color='red')
# Out:
# Text(0, 0.5, 'writing score')

# %%
# Displaying a scatter plot of math and reading scores

fig, ax=plt.subplots(figsize=(8,8))
ax.scatter(df['math score'],df['writing score'])
ax.set_title('math score Vs writing score',fontsize=10, color='red')
ax.set_xlabel("math score",fontsize=10, color='red')
ax.set_ylabel('writing score',fontsize=10,color='red')
# Out:
# Text(0, 0.5, 'writing score')

# %% [markdown]
# ### <u>Remarks</u>:
# ##### From the three scatter plots above showing the relationships between math & reading, reading & writing, and finally writing & math,
# ##### We see that there is a positive correlation between all three scores,  showing the strogest in correlation between writing & reading.
# ##### This strong positive correlation indicates that, most students who perform well in any of the test, equally performs well the others.

# %% [markdown]
# ## Seaborn-Boxplot

# %%
# Lets investigate the distribution of students' performance in math using seaborn-boxplot

fig, ax=plt.subplots(figsize=(8,8))
z=df['math score'].values # Create a sub dataframe that contains only the value of the interested variable.
sns.boxplot(z)
print(df["math score"].median()) # Calculate and print the median of the considered varaible.

# Notes;
# The line in the middle represents the meadian(66.0)
# The box in the middle shows the start of Q1 (25th percentile) and the end is at Q3 (75th percentile)
# The whiskers (left-right) shows the minimum and maximum quartiles.
# The dots to the left show "outliers"
# Out:
# 66.0

# %% [markdown]
# [Here is a link to the top of the page](#the_top)

# %% [markdown]
# ## Seabron-Scatter Plots for Investigations.

# %%
# Relationship between students' performance in math and writing based on parents level of eduaction."""

# Using seaborn
fig,ax=plt.subplots(figsize=(8,8))
ax=sns.scatterplot(x='math score',y='writing score',hue='parental level of education',style="parental level of education",data=df)

# %% [markdown]
# ### <u>Remarks<u/>:
# ##### Form the plot above, we see that there is no direct relationship between students' performance and parents' level of education.

# %%
# Investigating the relationship between writing & reading using their math scores as an indicator.

fig, ax= plt.subplots(figsize=(8,8))
ax=sns.scatterplot(x="reading score",y='writing score',hue='gender',style="gender",size="math score",sizes=(20,200),data=df)

# %% [markdown]
# ### <u>Remarks<u/>:
# ##### From the plot above, we see that:
# ##### Students' performance generally increases in writing & reading with females performing better,
# ##### Also, those who generally perform well in reading & writng also do perform well in math as indicated by the increase in the sizes of the dots.

# %%
# Investigating if there exist a relationship between students' performance in math and writing based on test preparation course."""

# Using seaborn
fig,ax=plt.subplots(figsize=(8,8))
ax=sns.scatterplot(x='math score',y='writing score',hue='test preparation course',style="test preparation course",data=df)
ax.grid(True)

# %% [markdown]
# ### <u>Remark<u/>:
# ##### From the plot above,  most students who scored above 60 in both test completed their preparatory course.

# %%
# Investigating how students' performance in both math & reading is related to their lunch type.

fig,ax=plt.subplots(figsize=(8,8))
ax=sns.scatterplot(x="math score",y="reading score",hue="lunch",style="lunch",data=df)
ax.grid(True)

# %% [markdown]
# ### <u>Remark<u/>:
# ##### The plot above shows that those students who scored above 60 in both math & reading take but standard lunch.

# %% [markdown]
# ## Seaborn-Lmplots for Interpretation.

# %%
# Displaying the relationship between students' performance in math & reading using lmplot.
ax=sns.lmplot(x="math score",y="reading score",height= 7,data=df)

# %%
# Displaying the relationship between students' performance in math & writing based on test preparation using lmplot
ax=sns.lmplot(x='math score',y='writing score',hue='test preparation course',height=7,data=df, ci=False)

# %% [markdown]
# ### <u>Remark<u/>:
# ##### From the plot, we see that students who completed thier test prep course scored better in both test.

# %%
# Displaying the relationship students' performance in math & writing based on test preparation using lmplot on two pearate plots.
ax=sns.lmplot(x='math score',y='writing score',col="test preparation course",height=5,data=df, ci=False)

# %% [markdown]
# ### <u>Remark<u/>:
# ##### From the plots, we see that students who completed thier test prep course scored better in both test as indicated by a slightly higher regression line.

# %%
# Displaying the relationship between students' performance in math & writing based on gender using lmplot
ax=sns.lmplot(x='math score',y='writing score',col='gender',height=5,data=df, ci=False)

# %% [markdown]
# ### <u> Remarks<u/>:
# ###### From the plots, we see that female students performed better in writing than their male counterparts.
# ###### Also more male students instead did well in math than writing.

# %% [markdown]
# ## Seaborn-Pairplot

# %%
# Ploting multiple variables using the pairplot function in seaborn.
g=sns.pairplot(df[['math score','writing score',"reading score"]],height=7,kind="reg")

# %% [markdown]
# ### Heat Map- to investigate Pearson correlation

# %% [markdown]
# * First we are going to create a dataset to use for the heat map- we will use a correlation dataset
# * ".corr()" is used to find all the pairwise correlation of all the columns of the dataframe. Any null values are automatically left out.
# * The ".corr()" compairs the values of the variables between 0-1.
# * Closser to -1(negative corr), +1(+ corr)
# * The closer to 1,or -1 the better.As one variable increse, the other also tends to increase/decrease.
# *  We can correlate only numerical values and not categorical values(maths core, reading score & writing score).

# %%
#Displaying Pearson Correlation (pc) for numeric variables.
pc=df[['math score','reading score','writing score']].corr()
pc
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
#Running a heat map for data frame pc.
hm=sns.heatmap(pc,annot=True,annot_kws={'size':40})

# %% [markdown]
# ### <u>Remarks<u/>:
# ##### The more darker the color, the lower the pearson corr between the variables, and the lighter the color, the stronger the corr.

# %% [markdown]
# ## Some basic explorations with our dataset.

# %%
# Summary statistics of our dataset(df) 
df.describe()
# Out:
#        math score  reading score  writing score  Total Score
# count  1000.00000    1000.000000    1000.000000   1000.000000
# mean     66.08900      69.169000      68.054000    203.312000
# std      15.16308      14.600192      15.195657     42.771978
# min       0.00000      17.000000      10.000000     27.000000
# 25%      57.00000      59.000000      57.750000    175.000000
# 50%      66.00000      70.000000      69.000000    205.000000
# 75%      77.00000      79.000000      79.000000    233.000000
# max     100.00000     100.000000     100.000000    300.000000

# %%
# Describing the type of each variable in our dataset.
df.dtypes
# Out:
# gender                         object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# Total Score                     int64
# dtype: object

# %%
# Displaying dataset containing only categorical variables.
category_var=df.select_dtypes("object")
category_var
# Out:
#      gender parental level of education         lunch test preparation course
# 0    female           bachelor's degree      standard                    none
# 1    female                some college      standard               completed
# 2    female             master's degree      standard                    none
# 3      male          associate's degree  free/reduced                    none
# 4      male                some college      standard                    none
# ..      ...                         ...           ...                     ...
# 995  female             master's degree      standard               completed
# 996    male                 high school  free/reduced                    none
# 997  female                 high school  free/reduced               completed
# 998  female                some college      standard               completed
# 999  female                some college  free/reduced                    none
#
# [1000 rows x 4 columns]

# %%
# Displaying dataset containing only numerical variables.
numeric_var=df.select_dtypes("number") # OR B=df.iloc[:,[4,5,6,7]]
numeric_var
#B
# Out:
#      math score  reading score  writing score  Total Score
# 0            72             72             74           218
# 1            69             90             88           247
# 2            90             95             93           278
# 3            47             57             44           148
# 4            76             78             75           229
# ..          ...            ...            ...           ...
# 995          88             99             95           282
# 996          62             55             55           172
# 997          59             71             65           195
# 998          68             78             77           223
# 999          77             86             86           249
#
# [1000 rows x 4 columns]

# %%
df
# Out:
#      gender parental level of education         lunch test preparation course  \
# 0    female           bachelor's degree      standard                    none
# 1    female                some college      standard               completed
# 2    female             master's degree      standard                    none
# 3      male          associate's degree  free/reduced                    none
# 4      male                some college      standard                    none
# ..      ...                         ...           ...                     ...
# 995  female             master's degree      standard               completed
# 996    male                 high school  free/reduced                    none
# 997  female                 high school  free/reduced               completed
# 998  female                some college      standard               completed
# 999  female                some college  free/reduced                    none
#
# ...

# %% [markdown]
# #### <u>Note<u/>:
# *Sorting gives the scores in ascending order, hence: Top= tail() & Bottom= head()*

# %%
# Top 10 best students in math.
df1=df.sort_values("math score").tail(10)
df1
# Out:
#      gender parental level of education         lunch test preparation course  \
# 306    male                some college      standard               completed
# 114  female           bachelor's degree      standard               completed
# 263  female                 high school      standard                    none
# 916    male           bachelor's degree      standard               completed
# 458  female           bachelor's degree      standard                    none
# 625    male                some college      standard               completed
# 623    male                some college      standard               completed
# 451  female                some college      standard                    none
# 962  female          associate's degree      standard                    none
# 149    male          associate's degree  free/reduced               completed
#
#      math score  reading score  writing score  Total Score
# ...

# %%
# Bottom 10 students in math.
df2=df.sort_values("math score").head(10)
df2
# Out:
#      gender parental level of education         lunch test preparation course  \
# 59   female            some high school  free/reduced                    none
# 980  female                 high school  free/reduced                    none
# 17   female            some high school  free/reduced                    none
# 787  female                some college      standard                    none
# 145  female                some college  free/reduced                    none
# 842  female                 high school  free/reduced               completed
# 338  female            some high school  free/reduced                    none
# 466  female          associate's degree  free/reduced                    none
# 91     male                 high school  free/reduced                    none
# 363  female            some high school  free/reduced                    none
#
#      math score  reading score  writing score  Total Score
# ...

# %%
# Top 10 students in reading.
df3=df.sort_values("reading score").tail(10)
df3
# Out:
#      gender parental level of education         lunch test preparation course  \
# 566  female           bachelor's degree  free/reduced               completed
# 114  female           bachelor's degree      standard               completed
# 712  female                some college      standard                    none
# 381    male          associate's degree      standard               completed
# 970  female           bachelor's degree      standard                    none
# 106  female             master's degree      standard                    none
# 594  female           bachelor's degree      standard               completed
# 962  female          associate's degree      standard                    none
# 179  female            some high school      standard               completed
# 458  female           bachelor's degree      standard                    none
#
#      math score  reading score  writing score  Total Score
# ...

# %%
# Bottom 10 students in readingWe .
df4=df.sort_values("reading score").head(10)
df4
# Out:
#      gender parental level of education         lunch test preparation course  \
# 59   female            some high school  free/reduced                    none
# 327    male                some college  free/reduced                    none
# 596    male                 high school  free/reduced                    none
# 980  female                 high school  free/reduced                    none
# 76     male            some high school      standard                    none
# 211    male                some college  free/reduced                    none
# 601  female                 high school      standard                    none
# 896    male                 high school  free/reduced                    none
# 466  female          associate's degree  free/reduced                    none
# 810    male            some high school      standard                    none
#
#      math score  reading score  writing score  Total Score
# ...

# %%
# Top 10 students in writing.
df5=df.sort_values("writing score").tail(10)
df5
# Out:
#      gender parental level of education         lunch test preparation course  \
# 403  female                 high school      standard               completed
# 685  female             master's degree      standard               completed
# 458  female           bachelor's degree      standard                    none
# 903  female           bachelor's degree  free/reduced               completed
# 179  female            some high school      standard               completed
# 970  female           bachelor's degree      standard                    none
# 106  female             master's degree      standard                    none
# 957  female             master's degree      standard                    none
# 916    male           bachelor's degree      standard               completed
# 114  female           bachelor's degree      standard               completed
#
#      math score  reading score  writing score  Total Score
# ...

# %%
# Bottom 10 students in writing.
df6=df.sort_values("writing score").tail(10)
df6
# Out:
#      gender parental level of education         lunch test preparation course  \
# 403  female                 high school      standard               completed
# 685  female             master's degree      standard               completed
# 458  female           bachelor's degree      standard                    none
# 903  female           bachelor's degree  free/reduced               completed
# 179  female            some high school      standard               completed
# 970  female           bachelor's degree      standard                    none
# 106  female             master's degree      standard                    none
# 957  female             master's degree      standard                    none
# 916    male           bachelor's degree      standard               completed
# 114  female           bachelor's degree      standard               completed
#
#      math score  reading score  writing score  Total Score
# ...

# %% [markdown]
# ### Calculating the sum of each column using the aggregate() function.

# %%
#Displaying the aggregate of the mean, max, min & std of our dataset.
A=df[["math score","reading score","writing score"]].aggregate(["mean","max","min","std"])
A
# Out:
#       math score  reading score  writing score
# mean    66.08900      69.169000      68.054000
# max    100.00000     100.000000     100.000000
# min      0.00000      17.000000      10.000000
# std     15.16308      14.600192      15.195657

# %%
# Caculating the total of all math scores of our original datset.
df["math score"].aggregate("sum")
# Out:
# 66089

# %%
# Caculating the total of all reading scores of our original datset.
df["reading score"].aggregate('sum')
# Out:
# 69169

# %%
# Caculating the total of all writing scores of our original datset.
df["writing score"].aggregate("sum")
# Out:
# 68054

# %% [markdown]
# [Here is a link to the top of this page](#the_top)
